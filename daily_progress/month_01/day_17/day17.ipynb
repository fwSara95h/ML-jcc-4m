# %% [markdown]
# # DAY 17 --

# %% [markdown]
# ### MC1 :

# %% [markdown]
# ---

# %% [markdown]
# ### MC2 :

# %% [markdown]
# ---

# %% [markdown]
# ### MC3 :

# %% [markdown]
# ---

# %% [markdown]
# ### MC4 :

# %% [markdown]
# ---
